# %% [markdown]
# <a href="https://www.kaggle.com/harini03/price-prediction-using-multiple-linear-regression?scriptVersionId=90081202" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# HARINI S
#
# 20AD015
#
# MACHINE LEARNING LABORATORY
#
# MULTIPLE LINEAR REGRESSION

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pickle

# %matplotlib inline

# %%
houseDF = pd.read_csv("../input/usa-housing-dataset/USA_Housing.csv")
houseDF

# %%
houseDF.info()

# %%
houseDF.describe()

# %%
houseDF.head()

# %%
houseDF.tail()

# %%
houseDF.isnull()

# %%
#DETECTING MISSING VALUES
houseDF.isnull().sum()

# %%
print(len(houseDF))

# %%
print(len(houseDF.columns))

# %%
houseDF.columns

# %%
houseDF.isna()

# %%
houseDF.isna().sum()

# %%
sns.heatmap(houseDF.corr(),annot=True)

# %%
#Eliminate the attribute 'Address' as it does not provide any relation between other attributes.
x=houseDF[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population']]
x

# %%
#Dependent Variable
y=houseDF['Price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
ln=LinearRegression(normalize=True).fit(x_train,y_train)

# %%
coeff_df=pd.DataFrame(ln.coef_,x.columns,columns=['Coefficient'])
print(coeff_df)

# %%
prediction=ln.predict(x_test)
plt.scatter(y_test,prediction)

# %%
df = pd.DataFrame({'Actual':round(y_test), 'Predicted':(prediction)})
df

# %%
sns.distplot((y_test-prediction), bins=50)

# %%
df1 = df.head(25)
df1.plot(kind='bar',figsize=(16,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, prediction))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, prediction))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))

# %%
pickle.dump(ln,open('model.pkl','wb'))

# %%
model=pickle.load(open('model.pkl','rb'))

# %%
print(model.predict([[21.680958,165491.107957,120813.535113,1230.964520,15.210737]]))

# %% [markdown]
# EVALUATION

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error

# %%
mean_absolute_error(y_test , prediction)

# %%
mean_squared_error(y_test , prediction)
